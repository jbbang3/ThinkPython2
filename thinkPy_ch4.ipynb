# %% [markdown]
# ## Chapter4
# ### Exercise 2
#
# Write an appropriately general set of functions that can draw flowers

# %%
import math
import turtle


def square(t, length):
    """Draws a square with sides of the given length.

    Returns the Turtle to the starting position and location.
    """
    for i in range(4):
        t.fd(length)
        t.lt(90)


def polyline(t, n, length, angle):
    """Draws n line segments.

    t: Turtle object
    n: number of line segments
    length: length of each segment
    angle: degrees between segments
    """
    for i in range(n):
        t.fd(length)
        t.lt(angle)


def polygon(t, n, length):
    """Draws a polygon with n sides.

    t: Turtle
    n: number of sides
    length: length of each side.
    """
    angle = 360.0/n
    polyline(t, n, length, angle)


def arc(t, r, angle):
    """Draws an arc with the given radius and angle.

    t: Turtle
    r: radius
    angle: angle subtended by the arc, in degrees
    """
    arc_length = 2 * math.pi * r * abs(angle) / 360
    n = int(arc_length / 4) + 3
    step_length = arc_length / n
    step_angle = float(angle) / n

    # making a slight left turn before starting reduces
    # the error caused by the linear approximation of the arc
    t.lt(step_angle/2)
    polyline(t, n, step_length, step_angle)
    t.rt(step_angle/2)


def circle(t, r):
    """Draws a circle with the given radius.

    t: Turtle
    r: radius
    """
    arc(t, r, 360)

def petal(t, r, angle):
    """Draws a petal using two arcs.

    t: Turtle
    r: radius of the arcs
    angle: angle (degrees) that subtends the arcs
    """
    for i in range(2):
        arc(t, r, angle)
        t.lt(180-angle)


def flower(t, n, r, angle):
    """Draws a flower with n petals.

    t: Turtle
    n: number of petals
    r: radius of the arcs
    angle: angle (degrees) that subtends the arcs
    """
    for i in range(n):
        petal(t, r, angle)
        t.lt(360.0/n)

if __name__=='__main__':
    bob=turtle.Turtle()
    flower(bob, 10, 50, 40)

# %% [markdown]
# Write a function to draw turtle pies

# %%
import math
import turtle

def triangle (t, s, b, angle):
    t.fd(s)
    t.lt(angle)
    t.fd(b)
    t.lt(angle)
    t.fd(s)
    t.lt(180)

def pie(t, n, l):
    angle=180-((n-2)*180/(2*n))
    print(angle)
    b=2*l*math.cos(math.radians(180-angle))
    print(b)
    for i in range(n):
        triangle(t,l,b,angle)

if __name__=='__main__':
    bob=turtle.Turtle()
    pie(bob, 8, 50)

    #triangle(bob, 60,30, 150)
# Out:
# 112.5
# 38.26834323650898

# %% [markdown]
# Write a fucntion to draw Archimedean spiral

# %%
import math
import turtle

def polyline(t, n, length, angle):
    """Draws n line segments.

    t: Turtle object
    n: number of line segments
    length: length of each segment
    angle: degrees between segments
    """
    for i in range(n):
        t.fd(length)
        t.lt(angle)

def arc(t, r, angle):
    """Draws an arc with the given radius and angle.

    t: Turtle
    r: radius
    angle: angle subtended by the arc, in degrees
    """
    arc_length = 2 * math.pi * r * abs(angle) / 360
    n = int(arc_length / 4) + 3
    step_length = arc_length / n
    step_angle = float(angle) / n

    # making a slight left turn before starting reduces
    # the error caused by the linear approximation of the arc
    t.lt(step_angle/2)
    polyline(t, n, step_length, step_angle)
    t.rt(step_angle/2)

def spiral(t, r, angle, n, a):
    """Draws an arc with the given radius and angle.

    t: Turtle
    r: radius
    angle: angle subtended by the arc, in degrees
    """
    step_angle = float(angle) / n
    
    for i in range(n):
        r=a*math.radians(step_angle*i)
        arc(t, r, step_angle)
    


if __name__=='__main__':
    bob=turtle.Turtle()
    spiral(bob, 30, 360*4, 20, 10)
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[1], line 51
#      49 if __name__=='__main__':
#      50     bob=turtle.Turtle()
# ---> 51     spiral(bob, 30, 360*4, 20, 10)
#
# Cell In[1], line 45, in spiral(t, r, angle, n, a)
#      43 for i in range(n):
#      44     r=a*math.radians(step_angle*i)
# ---> 45     arc(t, r, step_angle)
#
# Cell In[1], line 31, in arc(t, r, angle)
#      28 # making a slight left turn before starting reduces
#      29 # the error caused by the linear approximation of the arc
#      30 t.lt(step_angle/2)
# ---> 31 polyline(t, n, step_length, step_angle)
#      32 t.rt(step_angle/2)
#
# Cell In[1], line 14, in polyline(t, n, length, angle)
#      12 for i in range(n):
#      13     t.fd(length)
# ---> 14     t.lt(angle)
#
# File /opt/anaconda3/envs/general/lib/python3.12/turtle.py:1698, in TNavigator.left(self, angle)
# ...
